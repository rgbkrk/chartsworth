# %%
from chartsworth import Chartsworth

# %%
# You can pass in either channel IDs or channel names.
#
# Weird thing: if you use channel names you can't post images. It's a strange bug in the Slack API.
# Instead, rely on channel IDs. You can find them at the bottom of the channel details page.
#
#cw = Chartsworth(default_channel='#chartsy')

cw = Chartsworth(default_channel='C05LS2WCD3J')

# %%
from chartsworth.plot import create_monster_plot
fig = create_monster_plot()

# %%
fig

# %%
cw.post("test")

# %%
cw.post(fig, filename="mine.png")
